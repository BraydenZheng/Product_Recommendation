# %% [markdown]
# ### Regression

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report

# %% [markdown]
# Data Loading

# %%
sales = pd.read_csv('data/sales_dt.csv')
sales.head(3)
# Out:
#    discounted_price  actual_price  discount_percentage  rating  rating_count
# 0             399.0        1099.0                 0.64       1         24269
# 1             199.0        1899.0                 0.90       0          7928
# 2             154.0         399.0                 0.61       1         16905

# %%
X = sales.iloc[:, 1].values.reshape(-1, 1)
X
# Out:
# array([[1099.],
#        [1899.],
#        [ 399.],
#        ...,
#        [3080.],
#        [1890.],
#        [3690.]])

# %%
y = sales.iloc[:, 0].values
y
# Out:
# array([ 399.,  199.,  154., ..., 2219., 1399., 2863.])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=21)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
score = model.score(X_test, y_test)
print(f'score: {score}')
# Out:
# score: 0.5727347135136869

# %%
plt.scatter(X, y, color='blue')

plt.plot(X_test, y_pred, color='red')

plt.xlabel('Actual Price')
plt.ylabel('Discount Price')
plt.title('Linear Regression')

# Show the plot
plt.show()
